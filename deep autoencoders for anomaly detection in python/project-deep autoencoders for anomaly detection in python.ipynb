# %%
#imports
import numpy as np
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Input,Dense
from tensorflow.keras.models import Model

# %%
#create a synethetic data
def generate_data(samples=1000,features=20,anomalies=10):
    normal_size= (samples-anomalies,features)
    anomalies_size=(anomalies,features)
    normal_data=np.random.normal(0,1,size=normal_size)
    anomalies_data=np.random.uniform(-5,5,size=anomalies_size)
    data=np.vstack([normal_data,anomalies_data])
    np.random.shuffle(data)
    return data

data=generate_data()

# %%
type(data)
# Out:
# numpy.ndarray

# %%
data.shape
# Out:
# (1000, 20)

# %%
data[0,:]
# Out:
# array([-0.38914054,  0.30147886, -2.30717223, -0.42715849, -0.52494079,
#        -0.45451444, -0.36694853, -1.72845302, -0.3179811 , -0.62416868,
#        -1.47684611, -0.58005341,  1.48745178,  0.93788449, -1.44028006,
#         1.08261865,  0.05505279,  0.96059046, -1.01417098, -0.38947207])

# %%
#splitting the data into train and test sets
x_tr,x_test=train_test_split(data,test_size=0.25,random_state=42)
x_tr.shape
# Out:
# (750, 20)

# %%
x_test.shape
# Out:
# (250, 20)

# %%
scaler=MinMaxScaler()
x_tr=scaler.fit_transform(x_tr)
x_test=scaler.transform(x_test)

# %%
input_dim=x_tr.shape[1]
input_dim
# Out:
# 20

# %%
input_layer=Input(shape=(input_dim,))
#Encoder
encoded=Dense(128,activation='relu')(input_layer)
encoded=Dense(64,activation='relu')(encoded)
encoded=Dense(32,activation='relu')(encoded)
#Decoder
decoded=Dense(64,activation='relu')(encoded)
decoded=Dense(128,activation='relu')(decoded)
decoded=Dense(input_dim,activation='sigmoid')(decoded)

autoencoder=Model(inputs=input_layer,outputs=decoded)

# %%
autoencoder.compile(optimizer='adam',loss='mse')

# %%
#training the model
autoencoder.fit(x_tr,x_tr,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 99ms/step - loss: 0.0222 - val_loss: 0.0149
# Epoch 2/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0165 - val_loss: 0.0147
# Epoch 3/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0159 - val_loss: 0.0140
# Epoch 4/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0148 - val_loss: 0.0131
# Epoch 5/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0139 - val_loss: 0.0123
# Epoch 6/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0132 - val_loss: 0.0113
# Epoch 7/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0126 - val_loss: 0.0107
# Epoch 8/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0115 - val_loss: 0.0100
# Epoch 9/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0104 - val_loss: 0.0089
# Epoch 10/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0096 - val_loss: 0.0084
# Epoch 11/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0084 - val_loss: 0.0076
# Epoch 12/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0075 - val_loss: 0.0073
# Epoch 13/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0076 - val_loss: 0.0070
# Epoch 14/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0070 - val_loss: 0.0069
# Epoch 15/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0067 - val_loss: 0.0065
# Epoch 16/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 17/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0063 - val_loss: 0.0061
# Epoch 18/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 19/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 20/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 21/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0050 - val_loss: 0.0050
# Epoch 22/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0051 - val_loss: 0.0048
# Epoch 23/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0046 - val_loss: 0.0046
# Epoch 24/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 25/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 26/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0042 - val_loss: 0.0041
# Epoch 27/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0041
# Epoch 28/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0039 - val_loss: 0.0041
# Epoch 29/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0038 - val_loss: 0.0039
# Epoch 30/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 31/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0036 - val_loss: 0.0037
# Epoch 32/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0035 - val_loss: 0.0035
# Epoch 33/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0033 - val_loss: 0.0036
# Epoch 34/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032 - val_loss: 0.0033
# Epoch 35/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 36/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0029 - val_loss: 0.0031
# Epoch 37/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0028 - val_loss: 0.0030
# Epoch 38/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026 - val_loss: 0.0030
# Epoch 39/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 40/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0025 - val_loss: 0.0027
# Epoch 41/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0024 - val_loss: 0.0025
# Epoch 42/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0022 - val_loss: 0.0024
# Epoch 43/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0020 - val_loss: 0.0021
# Epoch 44/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0019 - val_loss: 0.0021
# Epoch 45/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 46/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 47/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0018
# Epoch 48/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0016 - val_loss: 0.0017
# Epoch 49/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0017
# Epoch 50/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 51/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0015
# Epoch 52/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 53/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 54/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 55/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0013
# Epoch 56/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 57/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 58/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 59/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.9767e-04 - val_loss: 0.0012
# Epoch 60/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 61/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7531e-04 - val_loss: 0.0011
# Epoch 62/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.7354e-04 - val_loss: 0.0011
# Epoch 63/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9831e-04 - val_loss: 0.0011
# Epoch 64/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.9576e-04 - val_loss: 0.0010
# Epoch 65/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.2538e-04 - val_loss: 9.9025e-04
# Epoch 66/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.3057e-04 - val_loss: 9.3699e-04
# Epoch 67/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7510e-04 - val_loss: 8.8980e-04
# Epoch 68/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.6328e-04 - val_loss: 9.6234e-04
# Epoch 69/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.7853e-04 - val_loss: 8.5630e-04
# Epoch 70/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 6.6348e-04 - val_loss: 7.7148e-04
# Epoch 71/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.9602e-04 - val_loss: 6.9016e-04
# Epoch 72/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.3348e-04 - val_loss: 7.0414e-04
# Epoch 73/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.0759e-04 - val_loss: 5.9905e-04
# Epoch 74/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.6467e-04 - val_loss: 5.4878e-04
# Epoch 75/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4748e-04 - val_loss: 6.0501e-04
# Epoch 76/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.5496e-04 - val_loss: 5.0897e-04
# Epoch 77/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3625e-04 - val_loss: 4.8904e-04
# Epoch 78/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.7490e-04 - val_loss: 4.6912e-04
# Epoch 79/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0020e-04 - val_loss: 4.6677e-04
# Epoch 80/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.8463e-04 - val_loss: 4.4694e-04
# Epoch 81/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3686e-04 - val_loss: 4.4593e-04
# Epoch 82/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1999e-04 - val_loss: 3.9597e-04
# Epoch 83/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8999e-04 - val_loss: 3.7936e-04
# Epoch 84/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1372e-04 - val_loss: 3.6298e-04
# Epoch 85/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6858e-04 - val_loss: 3.1396e-04
# Epoch 86/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8594e-04 - val_loss: 3.4389e-04
# Epoch 87/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7012e-04 - val_loss: 3.1360e-04
# Epoch 88/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3239e-04 - val_loss: 2.7978e-04
# Epoch 89/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3231e-04 - val_loss: 2.9087e-04
# Epoch 90/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4062e-04 - val_loss: 2.6360e-04
# Epoch 91/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0984e-04 - val_loss: 2.7053e-04
# Epoch 92/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0002e-04 - val_loss: 2.6245e-04
# Epoch 93/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1925e-04 - val_loss: 2.1540e-04
# Epoch 94/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8107e-04 - val_loss: 2.3552e-04
# Epoch 95/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0473e-04 - val_loss: 1.7955e-04
# Epoch 96/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5718e-04 - val_loss: 1.7315e-04
# Epoch 97/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4849e-04 - val_loss: 1.6228e-04
# Epoch 98/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3697e-04 - val_loss: 1.7117e-04
# Epoch 99/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3695e-04 - val_loss: 1.3405e-04
# Epoch 100/100
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1763e-04 - val_loss: 1.5443e-04

# %%
#Evaluate the model on test data
loss=autoencoder.evaluate(x_test,x_test)
print(f"mean squared error = {loss}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 4.4048e-04
# mean squared error = 0.0008017347427085042

# %%
#calculating the reconstruction errors for the anomalous data
preds=autoencoder.predict(x_test)
reconstruction_errors=preds-x_test
anomaly_threshold=0.1
anomaly_indices=np.where(reconstruction_errors>anomaly_threshold)[0]
unique_anomaly_indices=np.unique(anomaly_indices)
print(f"the first two reconstruction errors = {reconstruction_errors[:2]}")
print(f"anomaly indices = {unique_anomaly_indices}")
print(f"the number of the anomaly elements = {len(unique_anomaly_indices)}")
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# the first two reconstruction errors = [[ 0.00089734  0.00223528 -0.01643368 -0.0112798   0.00290935  0.00567957
#   -0.00317595  0.00428614 -0.00396277  0.01852792 -0.00408206  0.02143476
#    0.00642485 -0.01065798 -0.00437566 -0.00176496  0.01197668  0.0103968
#   -0.01117392 -0.0044121 ]
#  [-0.00188437  0.00762674  0.00574002 -0.01328129  0.00321044  0.00508281
#    0.00969081  0.00365943 -0.00188123 -0.003774   -0.00524873  0.00432992
#    0.00267401 -0.0031334   0.00614341  0.0006414   0.00060645  0.00995017
#   -0.0070885   0.00229623]]
# anomaly indices = [ 12  52 152 157 192 219 223 230 248]
# the number of the anomaly elements = 9

# %%
reconstruction_errors.shape
# Out:
# (250, 20)

# %% [markdown]
# References
#
# *blog post : https://readmedium.com/en/https:/levelup.gitconnected.com/build-deep-autoencoders-model-for-anomaly-detection-in-python-a-complete-guide-a7d0ec0e688
#
# *chatgpt conversation : https://chatgpt.com/share/67328e03-fb04-800f-a08b-97f467d444ae
